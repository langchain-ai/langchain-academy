# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("GOOGLE_API_KEY")

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to a project, `langchain-academy`.

# %%
_set_env("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage


messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)
llm.invoke(messages)
# Out:
# AIMessage(content='That\'s a great question! While whales (cetaceans) are certainly iconic, the ocean is home to a diverse array of other fascinating mammals. Here are some major groups and specific examples you should definitely learn about:\n\n1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**\n    These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice). They\'re characterized by their flippers.\n\n    *   **Seals (True Seals / Phocids):**\n        *   **Characteristics:** No external ear flaps, short front flippers, move on land by "wiggling" their bodies. They are generally more streamlined for water.\n        *   **Examples:**\n            *   **Harbor Seal:** Common along temperate coastlines.\n            *   **Harp Seal:** Known for their striking white pups.\n            *   **Elephant Seal:** The largest seals, famous for the male\'s proboscis (trunk-like nose) and deep-diving abilities.\n            *   **Leopard Seal:** Apex predator of the Antarctic, known for hunting penguins and other seals.\n\n    *   **Sea Lions (Eared Seals / Otariids):**\n        *   **Characteristics:** Have visible external ear flaps, long front flippers, and can rotate their hind flippers forward to "walk" on land. They are more agile on land than true seals.\n        *   **Examples:**\n            *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.\n            *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.\n\n    *   **Walruses:**\n        *   **Characteristics:** Distinctive long tusks (can be up to 3 feet!), large bodies, and bristly whiskers (vibrissae) used to find food on the seafloor. Found only in the Arctic.\n        *   **Fun Fact:** Both male and female walruses have tusks, which they use for hauling out onto ice, breaking breathing holes, and in dominance displays.\n\n2.  **Sirenians (Manatees and Dugongs)**\n    Often called "sea cows," these are gentle, herbivorous marine mammals that live in warm coastal waters.\n\n    *   **Manatees:**\n        *   **Characteristics:** Large, slow-moving, paddle-like tail. They primarily eat seagrass and other aquatic vegetation. Found in the Atlantic (Florida, Caribbean, Amazon, West Africa).\n        *   **Examples:** West Indian Manatee, Amazonian Manatee, African Manatee.\n\n    *   **Dugongs:**\n        *   **Characteristics:** Similar to manatees but have a fluke-like (dolphin-like) tail rather than a paddle. They are exclusively marine (manatees can enter freshwater). Found in the Indo-Pacific.\n\n3.  **Sea Otters**\n    These are the smallest marine mammals and are incredibly charismatic.\n\n    *   **Characteristics:** Dense fur (the densest of any animal!) for insulation (they don\'t have blubber), often seen floating on their backs, using rocks as tools to crack open shellfish.\n    *   **Habitat:** Coastal areas of the North Pacific.\n    *   **Fun Fact:** They are a keystone species, meaning their presence significantly impacts their ecosystem, particularly by controlling sea urchin populations that would otherwise decimate kelp forests.\n\n4.  **Polar Bears**\n    While often thought of as land animals, polar bears are classified as marine mammals because their lives are intrinsically tied to the ocean, particularly the sea ice.\n\n    *   **Characteristics:** Large, powerful predators, excellent swimmers, thick fur and a layer of blubber for insulation in the Arctic. They primarily hunt seals.\n    *   **Habitat:** Arctic regions.\n\nThis list gives you a fantastic starting point beyond just whales! Each group has unique adaptations and plays a vital role in their respective marine ecosystems. Which one sounds most interesting to dive into first?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='lc_ru ...

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great area to research! While whales (cetaceans) are fascinating, there's a whole world of other incredible ocean mammals. Here are some major groups and specific examples you should definitely learn about:
#
# 1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**
#     These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice).
#
#     *   **True Seals (Phocidae):**
#         *   **Characteristics:** No external ear flaps, move on land by wriggling their bodies (like a caterpillar), use their hind flippers for propulsion in water.
#         *   **Examples:**
#             *   **Harbor Seal:** Common in temperate coastal waters of the Northern Hemisphere.
#             *   **Grey Seal:** Larger, with a distinctive "horse-like" snout.
#             *   **Harp Seal:** Known for their striking white fur as pups.
#             *   **Leopard Seal:** An apex predator of the Antarctic, known for hunting penguins and other seals.
#             *   **Elephant Seals:** The largest seals, famous for their proboscis-like snout (males) and deep-diving abilities.
#
#     *   **Eared Seals (Otariidae - Sea Lions & Fur Seals):**
#         *   **Characteristics:** Have visible external ear flaps, can "walk" on land using their strong front flippers, use their front flippers for propulsion in water.
#         *   **Examples:**
#             *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.
#             *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.
#             *   **Galapagos Sea Lion:** Endemic to the Galapagos Islands, very playful and curious.
#             *   **Fur Seals:** A subgroup of eared seals, known for their thick, luxurious fur.
#
#     *   **Walruses (Odobenidae):**
#         *   **Characteristics:** Distinctive long tusks (can be found on both males and females), large, wrinkled bodies, found in Arctic waters.
#         *   **Example:**
#             *   **Walrus:** The only living species in its family, uses its tusks for hauling out onto ice, breaking breathing holes, and foraging.
#
# 2.  **Sirenians (Manatees and Dugongs)**
#     Often called "sea cows," these are gentle, herbivorous mammals that spend their entire lives in the water.
#
#     *   **Manatees:**
#         *   **Characteristics:** Paddle-like tail, found in shallow, warm coastal waters and rivers.
#         *   **Examples:**
#             *   **West Indian Manatee:** Found in the Caribbean, Florida, and parts of South America.
#             *   **Amazonian Manatee:** Freshwater species found in the Amazon River basin.
#             *   **African Manatee:** Found along the coast and rivers of West Africa.
#
#     *   **Dugongs:**
#         *   **Characteristics:** Fluke-like tail (similar to a whale's), found in warm coastal waters of the Indo-Pacific.
#         *   **Example:**
#             *   **Dugong:** The only strictly marine herbivorous mammal, often found grazing on seagrass beds.
#
# 3.  **Sea Otters (Mustelidae)**
#     These are the smallest marine mammals and are known for their incredibly dense fur.
#
#     *   **Characteristics:** Spend most of their lives in the water, often float on their backs, use tools (like rocks to crack open shellfish), very playful.
#     *   **Examples:**
#         *   **Southern Sea Otter (California Sea Otter):** Found along the coast of California.
#         *   **Northern Sea Otter:** Found from Alaska to Russia and Japan.
#
# 4.  **Polar Bears (Ursidae)**
#     While technically a bear, polar bears are considered marine mammals because their lives are intrinsically linked to the ocean, particularly sea ice.
#
#     *   **Characteristics:** Apex predators of the Arctic, excellent swimmers, thick layer of blubber and dense fur for insulation, primarily hunt seals.
#     *   **Example:**
#         *   **Polar Bear:** The largest living carnivore on Earth, perfectly adapted to life in the extreme cold.
#
# And don't forget, even within the "whale" category, there are **Dolphins and Porpoises**! While they are technically toothed whales, they are often thought of separately from the larger baleen whales or sperm whales.
#
# *   **Dolphins:** Generally more slender, conical teeth, often social and acrobatic (e.g., Bottlenose Dolphin, Spinner Dolphin, Orca/Killer Whale – which is actually the largest dolphin!).
# *   **Porpoises:** Generally smaller, more robust, spade-shaped teeth, and a triangular dorsal fin (e.g., Harbor Porpoise, Dall's Porpoise).
#
# Each of these groups has unique adaptations, behaviors, and conservation challenges. Happy researching!

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)

builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great area to research! While whales (cetaceans) are fascinating, there's a whole world of other incredible ocean mammals. Here are some major groups and specific examples you should definitely learn about:
#
# 1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**
#     These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice).
#
#     *   **True Seals (Phocidae):**
#         *   **Characteristics:** No external ear flaps, move on land by wriggling their bodies (like a caterpillar), use their hind flippers for propulsion in water.
#         *   **Examples:**
#             *   **Harbor Seal:** Common in temperate coastal waters of the Northern Hemisphere.
#             *   **Grey Seal:** Larger, with a distinctive "horse-like" snout.
#             *   **Harp Seal:** Known for their striking white fur as pups.
#             *   **Leopard Seal:** An apex predator of the Antarctic, known for hunting penguins and other seals.
#             *   **Elephant Seals:** The largest seals, famous for their proboscis-like snout (males) and deep-diving abilities.
#
#     *   **Eared Seals (Otariidae - Sea Lions & Fur Seals):**
#         *   **Characteristics:** Have visible external ear flaps, can "walk" on land using their strong front flippers, use their front flippers for propulsion in water.
#         *   **Examples:**
#             *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.
#             *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.
#             *   **Galapagos Sea Lion:** Endemic to the Galapagos Islands, very playful and curious.
#             *   **Fur Seals:** A subgroup of eared seals, known for their thick, luxurious fur.
#
#     *   **Walruses (Odobenidae):**
#         *   **Characteristics:** Distinctive long tusks (can be found on both males and females), large, wrinkled bodies, found in Arctic waters.
#         *   **Example:**
#             *   **Walrus:** The only living species in its family, uses its tusks for hauling out onto ice, breaking breathing holes, and foraging.
#
# 2.  **Sirenians (Manatees and Dugongs)**
#     Often called "sea cows," these are gentle, herbivorous mammals that spend their entire lives in the water.
#
#     *   **Manatees:**
#         *   **Characteristics:** Paddle-like tail, found in shallow, warm coastal waters and rivers.
#         *   **Examples:**
#             *   **West Indian Manatee:** Found in the Caribbean, Florida, and parts of South America.
#             *   **Amazonian Manatee:** Freshwater species found in the Amazon River basin.
#             *   **African Manatee:** Found along the coast and rivers of West Africa.
#
#     *   **Dugongs:**
#         *   **Characteristics:** Fluke-like tail (similar to a whale's), found in warm coastal waters of the Indo-Pacific.
#         *   **Example:**
#             *   **Dugong:** The only strictly marine herbivorous mammal, often found grazing on seagrass beds.
#
# 3.  **Sea Otters (Mustelidae)**
#     These are the smallest marine mammals and are known for their incredibly dense fur.
#
#     *   **Characteristics:** Spend most of their lives in the water, often float on their backs, use tools (like rocks to crack open shellfish), very playful.
#     *   **Examples:**
#         *   **Southern Sea Otter (California Sea Otter):** Found along the coast of California.
#         *   **Northern Sea Otter:** Found from Alaska to Russia and Japan.
#
# 4.  **Polar Bears (Ursidae)**
#     While technically a bear, polar bears are considered marine mammals because their lives are intrinsically linked to the ocean, particularly sea ice.
#
#     *   **Characteristics:** Apex predators of the Arctic, excellent swimmers, thick layer of blubber and dense fur for insulation, primarily hunt seals.
#     *   **Example:**
#         *   **Polar Bear:** The largest living carnivore on Earth, perfectly adapted to life in the extreme cold.
#
# And don't forget, even within the "whale" category, there are **Dolphins and Porpoises**! While they are technically toothed whales, they are often thought of separately from the larger baleen whales or sperm whales.
#
# *   **Dolphins:** Generally more slender, conical teeth, often social and acrobatic (e.g., Bottlenose Dolphin, Spinner Dolphin, Orca/Killer Whale – which is actually the largest dolphin!).
# *   **Porpoises:** Generally smaller, more robust, spade-shaped teeth, and a triangular dorsal fin (e.g., Harbor Porpoise, Dall's Porpoise).
#
# Each of these groups has unique adaptations, behaviors, and conservation challenges. Happy researching!

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great area to research! While whales (cetaceans) are fascinating, there's a whole world of other incredible ocean mammals. Here are some major groups and specific examples you should definitely learn about:
#
# 1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**
#     These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice).
#
#     *   **True Seals (Phocidae):**
#         *   **Characteristics:** No external ear flaps, move on land by wriggling their bodies (like a caterpillar), use their hind flippers for propulsion in water.
#         *   **Examples:**
#             *   **Harbor Seal:** Common in temperate coastal waters of the Northern Hemisphere.
#             *   **Grey Seal:** Larger, with a distinctive "horse-like" snout.
#             *   **Harp Seal:** Known for their striking white fur as pups.
#             *   **Leopard Seal:** An apex predator of the Antarctic, known for hunting penguins and other seals.
#             *   **Elephant Seals:** The largest seals, famous for their proboscis-like snout (males) and deep-diving abilities.
#
#     *   **Eared Seals (Otariidae - Sea Lions & Fur Seals):**
#         *   **Characteristics:** Have visible external ear flaps, can "walk" on land using their strong front flippers, use their front flippers for propulsion in water.
#         *   **Examples:**
#             *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.
#             *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.
#             *   **Galapagos Sea Lion:** Endemic to the Galapagos Islands, very playful and curious.
#             *   **Fur Seals:** A subgroup of eared seals, known for their thick, luxurious fur.
#
#     *   **Walruses (Odobenidae):**
#         *   **Characteristics:** Distinctive long tusks (can be found on both males and females), large, wrinkled bodies, found in Arctic waters.
#         *   **Example:**
#             *   **Walrus:** The only living species in its family, uses its tusks for hauling out onto ice, breaking breathing holes, and foraging.
#
# 2.  **Sirenians (Manatees and Dugongs)**
#     Often called "sea cows," these are gentle, herbivorous mammals that spend their entire lives in the water.
#
#     *   **Manatees:**
#         *   **Characteristics:** Paddle-like tail, found in shallow, warm coastal waters and rivers.
#         *   **Examples:**
#             *   **West Indian Manatee:** Found in the Caribbean, Florida, and parts of South America.
#             *   **Amazonian Manatee:** Freshwater species found in the Amazon River basin.
#             *   **African Manatee:** Found along the coast and rivers of West Africa.
#
#     *   **Dugongs:**
#         *   **Characteristics:** Fluke-like tail (similar to a whale's), found in warm coastal waters of the Indo-Pacific.
#         *   **Example:**
#             *   **Dugong:** The only strictly marine herbivorous mammal, often found grazing on seagrass beds.
#
# 3.  **Sea Otters (Mustelidae)**
#     These are the smallest marine mammals and are known for their incredibly dense fur.
#
#     *   **Characteristics:** Spend most of their lives in the water, often float on their backs, use tools (like rocks to crack open shellfish), very playful.
#     *   **Examples:**
#         *   **Southern Sea Otter (California Sea Otter):** Found along the coast of California.
#         *   **Northern Sea Otter:** Found from Alaska to Russia and Japan.
#
# 4.  **Polar Bears (Ursidae)**
#     While technically a bear, polar bears are considered marine mammals because their lives are intrinsically linked to the ocean, particularly sea ice.
#
#     *   **Characteristics:** Apex predators of the Arctic, excellent swimmers, thick layer of blubber and dense fur for insulation, primarily hunt seals.
#     *   **Example:**
#         *   **Polar Bear:** The largest living carnivore on Earth, perfectly adapted to life in the extreme cold.
#
# And don't forget, even within the "whale" category, there are **Dolphins and Porpoises**! While they are technically toothed whales, they are often thought of separately from the larger baleen whales or sperm whales.
#
# *   **Dolphins:** Generally more slender, conical teeth, often social and acrobatic (e.g., Bottlenose Dolphin, Spinner Dolphin, Orca/Killer Whale – which is actually the largest dolphin!).
# *   **Porpoises:** Generally smaller, more robust, spade-shaped teeth, and a triangular dorsal fin (e.g., Harbor Porpoise, Dall's Porpoise).
#
# Each of these groups has unique adaptations, behaviors, and conservation challenges. Happy researching!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
messages[-1:]
# Out:
# [HumanMessage(content='Tell me more about Narwhals!', additional_kwargs={}, response_metadata={}, name='Lance', id='75bb1da6-af79-446b-a202-8aef00ea6f07')]

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great area to research! While whales (cetaceans) are fascinating, there's a whole world of other incredible ocean mammals. Here are some major groups and specific examples you should definitely learn about:
#
# 1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**
#     These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice).
#
#     *   **True Seals (Phocidae):**
#         *   **Characteristics:** No external ear flaps, move on land by wriggling their bodies (like a caterpillar), use their hind flippers for propulsion in water.
#         *   **Examples:**
#             *   **Harbor Seal:** Common in temperate coastal waters of the Northern Hemisphere.
#             *   **Grey Seal:** Larger, with a distinctive "horse-like" snout.
#             *   **Harp Seal:** Known for their striking white fur as pups.
#             *   **Leopard Seal:** An apex predator of the Antarctic, known for hunting penguins and other seals.
#             *   **Elephant Seals:** The largest seals, famous for their proboscis-like snout (males) and deep-diving abilities.
#
#     *   **Eared Seals (Otariidae - Sea Lions & Fur Seals):**
#         *   **Characteristics:** Have visible external ear flaps, can "walk" on land using their strong front flippers, use their front flippers for propulsion in water.
#         *   **Examples:**
#             *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.
#             *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.
#             *   **Galapagos Sea Lion:** Endemic to the Galapagos Islands, very playful and curious.
#             *   **Fur Seals:** A subgroup of eared seals, known for their thick, luxurious fur.
#
#     *   **Walruses (Odobenidae):**
#         *   **Characteristics:** Distinctive long tusks (can be found on both males and females), large, wrinkled bodies, found in Arctic waters.
#         *   **Example:**
#             *   **Walrus:** The only living species in its family, uses its tusks for hauling out onto ice, breaking breathing holes, and foraging.
#
# 2.  **Sirenians (Manatees and Dugongs)**
#     Often called "sea cows," these are gentle, herbivorous mammals that spend their entire lives in the water.
#
#     *   **Manatees:**
#         *   **Characteristics:** Paddle-like tail, found in shallow, warm coastal waters and rivers.
#         *   **Examples:**
#             *   **West Indian Manatee:** Found in the Caribbean, Florida, and parts of South America.
#             *   **Amazonian Manatee:** Freshwater species found in the Amazon River basin.
#             *   **African Manatee:** Found along the coast and rivers of West Africa.
#
#     *   **Dugongs:**
#         *   **Characteristics:** Fluke-like tail (similar to a whale's), found in warm coastal waters of the Indo-Pacific.
#         *   **Example:**
#             *   **Dugong:** The only strictly marine herbivorous mammal, often found grazing on seagrass beds.
#
# 3.  **Sea Otters (Mustelidae)**
#     These are the smallest marine mammals and are known for their incredibly dense fur.
#
#     *   **Characteristics:** Spend most of their lives in the water, often float on their backs, use tools (like rocks to crack open shellfish), very playful.
#     *   **Examples:**
#         *   **Southern Sea Otter (California Sea Otter):** Found along the coast of California.
#         *   **Northern Sea Otter:** Found from Alaska to Russia and Japan.
#
# 4.  **Polar Bears (Ursidae)**
#     While technically a bear, polar bears are considered marine mammals because their lives are intrinsically linked to the ocean, particularly sea ice.
#
#     *   **Characteristics:** Apex predators of the Arctic, excellent swimmers, thick layer of blubber and dense fur for insulation, primarily hunt seals.
#     *   **Example:**
#         *   **Polar Bear:** The largest living carnivore on Earth, perfectly adapted to life in the extreme cold.
#
# And don't forget, even within the "whale" category, there are **Dolphins and Porpoises**! While they are technically toothed whales, they are often thought of separately from the larger baleen whales or sperm whales.
#
# *   **Dolphins:** Generally more slender, conical teeth, often social and acrobatic (e.g., Bottlenose Dolphin, Spinner Dolphin, Orca/Killer Whale – which is actually the largest dolphin!).
# *   **Porpoises:** Generally smaller, more robust, spade-shaped teeth, and a triangular dorsal fin (e.g., Harbor Porpoise, Dall's Porpoise).
#
# Each of these groups has unique adaptations, behaviors, and conservation challenges. Happy researching!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Narwhals are truly one of the most fascinating and enigmatic creatures of the Arctic! Often called the "unicorns of the sea" due to their distinctive tusk, they are a type of toothed whale (odontocete) closely related to beluga whales.
#
# Here's a deeper dive into what makes narwhals so unique:
#
# 1.  **The Tusk: A Sensory Organ, Not a Weapon**
#     *   **What it is:** The narwhal's famous "horn" is actually an elongated canine tooth that can grow up to 10 feet (3 meters) long in males, spiraling counter-clockwise. A small percentage of females also grow a tusk, and very rarely, a narwhal might have two tusks.
#     *   **Purpose:** For a long time, its function was a mystery. Scientists now believe it's primarily a highly sensitive **sensory organ**. It's covered in millions of nerve endings that can detect changes in water temperature, pressure, salinity, and even the presence of prey. It's like an underwater antenna!
#     *   **Other uses:** While not its primary function, it's also thought to be used for communication, navigating, and possibly for display during mating rituals. It's *not* used for fighting, breaking ice, or spearing fish.
#
# 2.  **Appearance & Adaptations**
#     *   **Size:** They are medium-sized whales, typically growing 13-18 feet (4-5.5 meters) long, not including the tusk.
#     *   **Coloration:** Young narwhals are mottled blue-gray, becoming more spotted and lighter with age. Older narwhals can be nearly white.
#     *   **No Dorsal Fin:** Unlike most whales, narwhals lack a dorsal fin. This is an adaptation to their icy environment, allowing them to swim easily under ice sheets without snagging.
#     *   **Blubber:** They have a thick layer of blubber to insulate them from the frigid Arctic waters.
#
# 3.  **Habitat & Distribution**
#     *   **Arctic Specialists:** Narwhals are exclusively found in the Arctic waters of Canada, Greenland, Norway, and Russia.
#     *   **Ice Edge Dwellers:** They prefer deep, ice-covered waters, often congregating near the ice edge, leads (cracks in the ice), and polynyas (areas of open water surrounded by ice).
#     *   **Migration:** They undertake seasonal migrations, moving closer to shore in summer and further offshore into deeper, ice-covered waters in winter.
#
# 4.  **Diet & Hunting**
#     *   **Suction Feeders:** Narwhals are suction feeders. They dive deep to hunt, creating a vacuum with their mouths to suck up prey.
#     *   **Diet:** Their diet consists mainly of Greenland halibut, cod, squid, and shrimp.
#
# 5.  **Social Behavior**
#     *   **Pods:** They are social animals, typically living in pods of 5-10 individuals, though larger aggregations of hundreds or even thousands can occur during migration.
#     *   **Communication:** They communicate using a variety of clicks, whistles, and trills.
#     *   **"Tusk Crossing":** Narwhals have been observed gently rubbing their tusks together, a behavior thought to be a form of social interaction or possibly to clean their tusks.
#
# 6.  **Deep Divers**
#     *   Narwhals are among the deepest-diving marine mammals. They can dive to depths of over 5,000 feet (1,500 meters) and hold their breath for up to 25 minutes, often making multiple deep dives in a row.
#
# 7.  **Conservation Status & Threats**
#     *   **IUCN Status:** Globally, narwhals are listed as "Least Concern," but some populations are considered "Near Threatened" or "Vulnerable."
#     *   **Threats:**
#         *   **Climate Change:** This is their biggest threat. Melting sea ice reduces their habitat, changes prey distribution, and makes them more vulnerable to predators like killer whales.
#         *   **Noise Pollution:** Increased shipping and oil/gas exploration in the Arctic create underwater noise that can disrupt their communication and navigation.
#         *   **Entanglement:** They can get entangled in fishing gear.
#         *   **Hunting:** Indigenous communities in the Arctic have historically hunted narwhals for their meat, blubber, and tusks, which is managed by quotas.
#
# Narwhals are truly a marvel of evolution, perfectly adapted to one of the planet's harshest environments. Their mysterious nature and unique tusk continue to captivate scientists and the public alike.

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=llm,
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output['messages'][-1]
# Out:
# AIMessage(content='Narwhals are truly one of the most fascinating and enigmatic creatures of the Arctic! Often called the "unicorns of the sea" due to their distinctive tusk, they are a type of toothed whale (odontocete) closely related to beluga whales.\n\nHere\'s a deeper dive into what makes narwhals so unique:\n\n1.  **The Tusk: A Sensory Organ, Not a Weapon**\n    *   **What it is:** The narwhal\'s famous "horn" is actually an elongated canine tooth that can grow up to 10 feet (3 meters) long in males, spiraling counter-clockwise. A small percentage of females also grow a tusk, and very rarely, a narwhal might have two tusks.\n    *   **Purpose:** For a long time, its function was a mystery. Scientists now believe it\'s primarily a highly sensitive **sensory organ**. It\'s covered in millions of nerve endings that can detect changes in water temperature, pressure, salinity, and even the presence of prey. It\'s like an underwater antenna!\n    *   **Other uses:** While not its primary function, it\'s also thought to be used for communication, navigating, and possibly for display during mating rituals. It\'s *not* used for fighting, breaking ice, or spearing fish.\n\n2.  **Appearance & Adaptations**\n    *   **Size:** They are medium-sized whales, typically growing 13-18 feet (4-5.5 meters) long, not including the tusk.\n    *   **Coloration:** Young narwhals are mottled blue-gray, becoming more spotted and lighter with age. Older narwhals can be nearly white.\n    *   **No Dorsal Fin:** Unlike most whales, narwhals lack a dorsal fin. This is an adaptation to their icy environment, allowing them to swim easily under ice sheets without snagging.\n    *   **Blubber:** They have a thick layer of blubber to insulate them from the frigid Arctic waters.\n\n3.  **Habitat & Distribution**\n    *   **Arctic Specialists:** Narwhals are exclusively found in the Arctic waters of Canada, Greenland, Norway, and Russia.\n    *   **Ice Edge Dwellers:** They prefer deep, ice-covered waters, often congregating near the ice edge, leads (cracks in the ice), and polynyas (areas of open water surrounded by ice).\n    *   **Migration:** They undertake seasonal migrations, moving closer to shore in summer and further offshore into deeper, ice-covered waters in winter.\n\n4.  **Diet & Hunting**\n    *   **Suction Feeders:** Narwhals are suction feeders. They dive deep to hunt, creating a vacuum with their mouths to suck up prey.\n    *   **Diet:** Their diet consists mainly of Greenland halibut, cod, squid, and shrimp.\n\n5.  **Social Behavior**\n    *   **Pods:** They are social animals, typically living in pods of 5-10 individuals, though larger aggregations of hundreds or even thousands can occur during migration.\n    *   **Communication:** They communicate using a variety of clicks, whistles, and trills.\n    *   **"Tusk Crossing":** Narwhals have been observed gently rubbing their tusks together, a behavior thought to be a form of social interaction or possibly to clean their tusks.\n\n6.  **Deep Divers**\n    *   Narwhals are among the deepest-diving marine mammals. They can dive to depths of over 5,000 feet (1,500 meters) and hold their breath for up to 25 minutes, often making multiple deep dives in a row.\n\n7.  **Conservation Status & Threats**\n    *   **IUCN Status:** Globally, narwhals are listed as "Least Concern," but some populations are considered "Near Threatened" or "Vulnerable."\n    *   **Threats:**\n        *   **Climate Change:** This is their biggest threat. Melting sea ice reduces their habitat, changes prey distribution, and makes them more vulnerable to predators like killer whales.\n        *   **Noise Pollution:** Increased shipping and oil/gas exploration in the Arctic create underwater noise that can disrupt their communication and navigation.\n        *   **Entanglement:** They can get entangled in fishing gear.\n        *   **Hunting:** Indigenous communities in the Arctic have historically hunted narwhals for thei ...

# %%
messages
# Out:
# [AIMessage(content='Hi.', additional_kwargs={}, response_metadata={}, name='Bot', id='1'),
#  HumanMessage(content='Hi.', additional_kwargs={}, response_metadata={}, name='Lance', id='2'),
#  AIMessage(content='So you said you were researching ocean mammals?', additional_kwargs={}, response_metadata={}, name='Bot', id='3'),
#  HumanMessage(content='Yes, I know about whales. But what others should I learn about?', additional_kwargs={}, response_metadata={}, name='Lance', id='4'),
#  AIMessage(content='That\'s a great area to research! While whales (cetaceans) are fascinating, there\'s a whole world of other incredible ocean mammals. Here are some major groups and specific examples you should definitely learn about:\n\n1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**\n    These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice).\n\n    *   **True Seals (Phocidae):**\n        *   **Characteristics:** No external ear flaps, move on land by wriggling their bodies (like a caterpillar), use their hind flippers for propulsion in water.\n        *   **Examples:**\n            *   **Harbor Seal:** Common in temperate coastal waters of the Northern Hemisphere.\n            *   **Grey Seal:** Larger, with a distinctive "horse-like" snout.\n            *   **Harp Seal:** Known for their striking white fur as pups.\n            *   **Leopard Seal:** An apex predator of the Antarctic, known for hunting penguins and other seals.\n            *   **Elephant Seals:** The largest seals, famous for their proboscis-like snout (males) and deep-diving abilities.\n\n    *   **Eared Seals (Otariidae - Sea Lions & Fur Seals):**\n        *   **Characteristics:** Have visible external ear flaps, can "walk" on land using their strong front flippers, use their front flippers for propulsion in water.\n        *   **Examples:**\n            *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.\n            *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.\n            *   **Galapagos Sea Lion:** Endemic to the Galapagos Islands, very playful and curious.\n            *   **Fur Seals:** A subgroup of eared seals, known for their thick, luxurious fur.\n\n    *   **Walruses (Odobenidae):**\n        *   **Characteristics:** Distinctive long tusks (can be found on both males and females), large, wrinkled bodies, found in Arctic waters.\n        *   **Example:**\n            *   **Walrus:** The only living species in its family, uses its tusks for hauling out onto ice, breaking breathing holes, and foraging.\n\n2.  **Sirenians (Manatees and Dugongs)**\n    Often called "sea cows," these are gentle, herbivorous mammals that spend their entire lives in the water.\n\n    *   **Manatees:**\n        *   **Characteristics:** Paddle-like tail, found in shallow, warm coastal waters and rivers.\n        *   **Examples:**\n            *   **West Indian Manatee:** Found in the Caribbean, Florida, and parts of South America.\n            *   **Amazonian Manatee:** Freshwater species found in the Amazon River basin.\n            *   **African Manatee:** Found along the coast and rivers of West Africa.\n\n    *   **Dugongs:**\n        *   **Characteristics:** Fluke-like tail (similar to a whale\'s), found in warm coastal waters of the Indo-Pacific.\n        *   **Example:**\n            *   **Dugong:** The only strictly marine herbivorous mammal, often found grazing on seagrass beds.\n\n3.  **Sea Otters (Mustelidae)**\n    These are the smallest marine mammals and are known for their incredibly dense fur.\n\n    *   **Characteristics:** Spend most of their lives in the water, often float on their backs, use tools (like rocks to crack open shellfish), very playful.\n    *   **Examples:**\n        *   **Southern Sea Otter (California Sea Otter):** Found along the coast of California.\n        *   **Northern Sea Otter:** Found from Alaska to Russia and Japan.\n\n4.  **Polar Bears (Ursidae)**\n    While technically a bear, polar bears are considered marine mammals because their lives are intrinsically linked to the ocean, particularly sea ice.\n\n    *   **Characteristics:** Apex predators of the Arctic, excellent swimmers, thick layer of blubber and dense fur for insulation, primarily hunt seals.\n    *   **Example:**\n        *   **Polar Bear:** The largest living carnivore on Earth, perfectly adapted to life in the extreme c ...
#  HumanMessage(content='Tell me more about Narwhals!', additional_kwargs={}, response_metadata={}, name='Lance', id='75bb1da6-af79-446b-a202-8aef00ea6f07'),
#  AIMessage(content='Narwhals are truly one of the most fascinating and enigmatic creatures of the Arctic! Often called the "unicorns of the sea" due to their distinctive tusk, they are a type of toothed whale (odontocete) closely related to beluga whales.\n\nHere\'s a deeper dive into what makes narwhals so unique:\n\n1.  **The Tusk: A Sensory Organ, Not a Weapon**\n    *   **What it is:** The narwhal\'s famous "horn" is actually an elongated canine tooth that can grow up to 10 feet (3 meters) long in males, spiraling counter-clockwise. A small percentage of females also grow a tusk, and very rarely, a narwhal might have two tusks.\n    *   **Purpose:** For a long time, its function was a mystery. Scientists now believe it\'s primarily a highly sensitive **sensory organ**. It\'s covered in millions of nerve endings that can detect changes in water temperature, pressure, salinity, and even the presence of prey. It\'s like an underwater antenna!\n    *   **Other uses:** While not its primary function, it\'s also thought to be used for communication, navigating, and possibly for display during mating rituals. It\'s *not* used for fighting, breaking ice, or spearing fish.\n\n2.  **Appearance & Adaptations**\n    *   **Size:** They are medium-sized whales, typically growing 13-18 feet (4-5.5 meters) long, not including the tusk.\n    *   **Coloration:** Young narwhals are mottled blue-gray, becoming more spotted and lighter with age. Older narwhals can be nearly white.\n    *   **No Dorsal Fin:** Unlike most whales, narwhals lack a dorsal fin. This is an adaptation to their icy environment, allowing them to swim easily under ice sheets without snagging.\n    *   **Blubber:** They have a thick layer of blubber to insulate them from the frigid Arctic waters.\n\n3.  **Habitat & Distribution**\n    *   **Arctic Specialists:** Narwhals are exclusively found in the Arctic waters of Canada, Greenland, Norway, and Russia.\n    *   **Ice Edge Dwellers:** They prefer deep, ice-covered waters, often congregating near the ice edge, leads (cracks in the ice), and polynyas (areas of open water surrounded by ice).\n    *   **Migration:** They undertake seasonal migrations, moving closer to shore in summer and further offshore into deeper, ice-covered waters in winter.\n\n4.  **Diet & Hunting**\n    *   **Suction Feeders:** Narwhals are suction feeders. They dive deep to hunt, creating a vacuum with their mouths to suck up prey.\n    *   **Diet:** Their diet consists mainly of Greenland halibut, cod, squid, and shrimp.\n\n5.  **Social Behavior**\n    *   **Pods:** They are social animals, typically living in pods of 5-10 individuals, though larger aggregations of hundreds or even thousands can occur during migration.\n    *   **Communication:** They communicate using a variety of clicks, whistles, and trills.\n    *   **"Tusk Crossing":** Narwhals have been observed gently rubbing their tusks together, a behavior thought to be a form of social interaction or possibly to clean their tusks.\n\n6.  **Deep Divers**\n    *   Narwhals are among the deepest-diving marine mammals. They can dive to depths of over 5,000 feet (1,500 meters) and hold their breath for up to 25 minutes, often making multiple deep dives in a row.\n\n7.  **Conservation Status & Threats**\n    *   **IUCN Status:** Globally, narwhals are listed as "Least Concern," but some populations are considered "Near Threatened" or "Vulnerable."\n    *   **Threats:**\n        *   **Climate Change:** This is their biggest threat. Melting sea ice reduces their habitat, changes prey distribution, and makes them more vulnerable to predators like killer whales.\n        *   **Noise Pollution:** Increased shipping and oil/gas exploration in the Arctic create underwater noise that can disrupt their communication and navigation.\n        *   **Entanglement:** They can get entangled in fishing gear.\n        *   **Hunting:** Indigenous communities in the Arctic have historically hunted narwhals for the ...
#  HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter=llm,
            allow_partial=False
        )
# Out:
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %%
messages_out_trim
# Out:
# {'messages': [AIMessage(content='Hi.', additional_kwargs={}, response_metadata={}, name='Bot', id='1'),
#   HumanMessage(content='Hi.', additional_kwargs={}, response_metadata={}, name='Lance', id='2'),
#   AIMessage(content='So you said you were researching ocean mammals?', additional_kwargs={}, response_metadata={}, name='Bot', id='3'),
#   HumanMessage(content='Yes, I know about whales. But what others should I learn about?', additional_kwargs={}, response_metadata={}, name='Lance', id='4'),
#   AIMessage(content='That\'s a great area to research! While whales (cetaceans) are fascinating, there\'s a whole world of other incredible ocean mammals. Here are some major groups and specific examples you should definitely learn about:\n\n1.  **Pinnipeds (Seals, Sea Lions, and Walruses)**\n    These are semi-aquatic marine mammals, meaning they spend time both in the water and on land (or ice).\n\n    *   **True Seals (Phocidae):**\n        *   **Characteristics:** No external ear flaps, move on land by wriggling their bodies (like a caterpillar), use their hind flippers for propulsion in water.\n        *   **Examples:**\n            *   **Harbor Seal:** Common in temperate coastal waters of the Northern Hemisphere.\n            *   **Grey Seal:** Larger, with a distinctive "horse-like" snout.\n            *   **Harp Seal:** Known for their striking white fur as pups.\n            *   **Leopard Seal:** An apex predator of the Antarctic, known for hunting penguins and other seals.\n            *   **Elephant Seals:** The largest seals, famous for their proboscis-like snout (males) and deep-diving abilities.\n\n    *   **Eared Seals (Otariidae - Sea Lions & Fur Seals):**\n        *   **Characteristics:** Have visible external ear flaps, can "walk" on land using their strong front flippers, use their front flippers for propulsion in water.\n        *   **Examples:**\n            *   **California Sea Lion:** Very common, often seen in harbors and on docks, known for their barking.\n            *   **Steller Sea Lion:** The largest species of sea lion, found in the North Pacific.\n            *   **Galapagos Sea Lion:** Endemic to the Galapagos Islands, very playful and curious.\n            *   **Fur Seals:** A subgroup of eared seals, known for their thick, luxurious fur.\n\n    *   **Walruses (Odobenidae):**\n        *   **Characteristics:** Distinctive long tusks (can be found on both males and females), large, wrinkled bodies, found in Arctic waters.\n        *   **Example:**\n            *   **Walrus:** The only living species in its family, uses its tusks for hauling out onto ice, breaking breathing holes, and foraging.\n\n2.  **Sirenians (Manatees and Dugongs)**\n    Often called "sea cows," these are gentle, herbivorous mammals that spend their entire lives in the water.\n\n    *   **Manatees:**\n        *   **Characteristics:** Paddle-like tail, found in shallow, warm coastal waters and rivers.\n        *   **Examples:**\n            *   **West Indian Manatee:** Found in the Caribbean, Florida, and parts of South America.\n            *   **Amazonian Manatee:** Freshwater species found in the Amazon River basin.\n            *   **African Manatee:** Found along the coast and rivers of West Africa.\n\n    *   **Dugongs:**\n        *   **Characteristics:** Fluke-like tail (similar to a whale\'s), found in warm coastal waters of the Indo-Pacific.\n        *   **Example:**\n            *   **Dugong:** The only strictly marine herbivorous mammal, often found grazing on seagrass beds.\n\n3.  **Sea Otters (Mustelidae)**\n    These are the smallest marine mammals and are known for their incredibly dense fur.\n\n    *   **Characteristics:** Spend most of their lives in the water, often float on their backs, use tools (like rocks to crack open shellfish), very playful.\n    *   **Examples:**\n        *   **Southern Sea Otter (California Sea Otter):** Found along the coast of California.\n        *   **Northern Sea Otter:** Found from Alaska to Russia and Japan.\n\n4.  **Polar Bears (Ursidae)**\n    While technically a bear, polar bears are considered marine mammals because their lives are intrinsically linked to the ocean, particularly sea ice.\n\n    *   **Characteristics:** Apex predators of the Arctic, excellent swimmers, thick layer of blubber and dense fur for insulation, primarily hunt seals.\n    *   **Example:**\n        *   **Polar Bear:** The largest living carnivore on Earth, perfectly adapted to life in the extreme  ...
#   HumanMessage(content='Tell me more about Narwhals!', additional_kwargs={}, response_metadata={}, name='Lance', id='75bb1da6-af79-446b-a202-8aef00ea6f07'),
#   AIMessage(content='Narwhals are truly one of the most fascinating and enigmatic creatures of the Arctic! Often called the "unicorns of the sea" due to their distinctive tusk, they are a type of toothed whale (odontocete) closely related to beluga whales.\n\nHere\'s a deeper dive into what makes narwhals so unique:\n\n1.  **The Tusk: A Sensory Organ, Not a Weapon**\n    *   **What it is:** The narwhal\'s famous "horn" is actually an elongated canine tooth that can grow up to 10 feet (3 meters) long in males, spiraling counter-clockwise. A small percentage of females also grow a tusk, and very rarely, a narwhal might have two tusks.\n    *   **Purpose:** For a long time, its function was a mystery. Scientists now believe it\'s primarily a highly sensitive **sensory organ**. It\'s covered in millions of nerve endings that can detect changes in water temperature, pressure, salinity, and even the presence of prey. It\'s like an underwater antenna!\n    *   **Other uses:** While not its primary function, it\'s also thought to be used for communication, navigating, and possibly for display during mating rituals. It\'s *not* used for fighting, breaking ice, or spearing fish.\n\n2.  **Appearance & Adaptations**\n    *   **Size:** They are medium-sized whales, typically growing 13-18 feet (4-5.5 meters) long, not including the tusk.\n    *   **Coloration:** Young narwhals are mottled blue-gray, becoming more spotted and lighter with age. Older narwhals can be nearly white.\n    *   **No Dorsal Fin:** Unlike most whales, narwhals lack a dorsal fin. This is an adaptation to their icy environment, allowing them to swim easily under ice sheets without snagging.\n    *   **Blubber:** They have a thick layer of blubber to insulate them from the frigid Arctic waters.\n\n3.  **Habitat & Distribution**\n    *   **Arctic Specialists:** Narwhals are exclusively found in the Arctic waters of Canada, Greenland, Norway, and Russia.\n    *   **Ice Edge Dwellers:** They prefer deep, ice-covered waters, often congregating near the ice edge, leads (cracks in the ice), and polynyas (areas of open water surrounded by ice).\n    *   **Migration:** They undertake seasonal migrations, moving closer to shore in summer and further offshore into deeper, ice-covered waters in winter.\n\n4.  **Diet & Hunting**\n    *   **Suction Feeders:** Narwhals are suction feeders. They dive deep to hunt, creating a vacuum with their mouths to suck up prey.\n    *   **Diet:** Their diet consists mainly of Greenland halibut, cod, squid, and shrimp.\n\n5.  **Social Behavior**\n    *   **Pods:** They are social animals, typically living in pods of 5-10 individuals, though larger aggregations of hundreds or even thousands can occur during migration.\n    *   **Communication:** They communicate using a variety of clicks, whistles, and trills.\n    *   **"Tusk Crossing":** Narwhals have been observed gently rubbing their tusks together, a behavior thought to be a form of social interaction or possibly to clean their tusks.\n\n6.  **Deep Divers**\n    *   Narwhals are among the deepest-diving marine mammals. They can dive to depths of over 5,000 feet (1,500 meters) and hold their breath for up to 25 minutes, often making multiple deep dives in a row.\n\n7.  **Conservation Status & Threats**\n    *   **IUCN Status:** Globally, narwhals are listed as "Least Concern," but some populations are considered "Near Threatened" or "Vulnerable."\n    *   **Threats:**\n        *   **Climate Change:** This is their biggest threat. Melting sea ice reduces their habitat, changes prey distribution, and makes them more vulnerable to predators like killer whales.\n        *   **Noise Pollution:** Increased shipping and oil/gas exploration in the Arctic create underwater noise that can disrupt their communication and navigation.\n        *   **Entanglement:** They can get entangled in fishing gear.\n        *   **Hunting:** Indigenous communities in the Arctic have historically hunted narwhals for th ...
#   HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance', id='d55738fa-c405-44ea-b8e5-fb51422ffc55'),
#   HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance', id='fee1c509-208e-4149-9d9d-5addbdd2f510'),
#   AIMessage(content='Orcas (also known as Killer Whales) are **truly global citizens of the ocean!**\n\nThey are found in **every single ocean basin** on Earth, making them one of the most widely distributed mammals.\n\nWhile they live worldwide, they tend to prefer **cooler, more productive waters** where food is abundant. This means you\'ll find them:\n\n*   **From the Arctic to the Antarctic:** They thrive in polar regions, often near ice edges.\n*   **Along coastlines:** Many populations are found in coastal waters, bays, and estuaries.\n*   **In the open ocean:** They also travel vast distances across deep ocean waters.\n\nSome of the most well-known areas where Orcas live include:\n\n*   **The Pacific Northwest (USA and Canada):** Famous for its resident and transient populations.\n*   **Alaska:** Abundant populations, especially in the Gulf of Alaska and Prince William Sound.\n*   **Norway and Iceland:** Known for large aggregations, often following herring runs.\n*   **The Southern Ocean (Antarctica):** Home to several distinct ecotypes, including those that hunt seals by creating waves.\n*   **Patagonia (Argentina):** Famous for their unique "intentional stranding" hunting technique for seal pups.\n*   **Japan and Russia:** Significant populations in the North Pacific.\n*   **Australia and New Zealand:** Found in various coastal and offshore areas.\n*   **South Africa:** Often seen along the coast.\n\nSo, in short, if there\'s an ocean, there\'s a good chance Orcas live there!', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='lc_run--228c9626-f6cf-4515-9da9-7bb913661814-0', usage_metadata={'input_tokens': 16, 'output_tokens': 1150, 'total_tokens': 1166, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 815}})]}

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
